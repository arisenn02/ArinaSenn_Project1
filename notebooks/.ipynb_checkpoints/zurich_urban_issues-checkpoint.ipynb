# %%
#load data
import pandas as pd
raw_zwn_issues = pd.read_csv("../data/raw/zwn_meldungen.csv")
raw_zwn_issues.head((3))

#select useful coloumns
subset = raw_zwn_issues[["service_name","requested_datetime","e","n"]]

#define new coloumn names
new_names = {
    "service_name":"category",
    "e":"East",
    "n":"North",
    "requested_datetime":"report_time",
}
subset = subset.rename(columns=new_names)

subset["report_time"] = pd.to_datetime(subset["report_time"], format ="%Y-%m-%dT%H:%M:%S")

import geopandas as gpd
from shapely.geometry import Point
subset_gdf = gpd.GeoDataFrame(subset,geometry=gpd.points_from_xy(subset["East"], subset["North"])
                             )
subset_gdf.head((3))
subset_gdf.dtypes
# Out:
# category                  str
# report_time    datetime64[us]
# East                    int64
# North                   int64
# geometry             geometry
# dtype: object
